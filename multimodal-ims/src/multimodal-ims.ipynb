# %%
from vitessce import (
    VitessceConfig,
    ViewType as vt,
    CoordinationType as ct,
    DataType as dt,
    FileType as ft,
    MultiImageWrapper,
    OmeTiffWrapper,
    BASE_URL_PLACEHOLDER
)
import json
from urllib.parse import quote_plus
from os.path import join
import os

# %%
PATH_TO_EXPORT_DIRECTORY = join("..", "..", "hubmap-publication-page", "data", "multimodal-ims")
VIGNETTE_DIR = join("..", "..", "hubmap-publication-page", "vignettes", "vignette_07")

# %%
json_config = """
{
      "version": "1.0.16",
      "name": "3D Human Liver with annotations",
      "uid": "3D Human Liver with annotations",
      "description": "",
      "datasets": [
        {
          "uid": "human-liver-annot",
          "name": "Human dataset",
          "files": [
            {
              "fileType": "image.ome-tiff",
              "url": "https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_3d.raster.pyramid.ome.tiff"
            },
            {
                "fileType": "obsSegmentations.ome-tiff",
                "url": "https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.cell_ids.ome.tiff",
                "coordinationValues": {
                    "obsType": "cell"
                }
            },
            {
              "fileType": "anndata-cells.zarr",
              "url": "https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr",
              "options": {
                "mappings": {
                  "Lipid/metabolite-based t-SNE": {
                    "dims": [
                      0,
                      1
                    ],
                    "key": "obsm/X_lipmet_tsne"
                  },
                  "Protein-based t-SNE": {
                    "dims": [
                      0,
                      1
                    ],
                    "key": "obsm/X_protein_tsne"
                  }
                },
                "xy": "obsm/X_spatial"
              }
            },
            {
              "fileType": "anndata-cell-sets.zarr",
              "url": "https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr",
              "options": [
                {
                  "groupName": "Protein-based Clustering",
                  "setName": "obs/Protein Cluster"
                },
                {
                  "groupName": "Lipid/metabolite-based Clustering",
                  "setName": "obs/Lipmet Cluster"
                }
              ]
            },
            {
              "fileType": "anndata-expression-matrix.zarr",
              "url": "https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr",
              "options": {
                "geneAlias": "var/feature_name",
                "matrix": "layers/X_uint8"
              }
            }
          ]
        }
      ],
      "coordinationSpace": {
        "embeddingType": {
          "A": "Protein-based t-SNE",
          "B": "Lipid/metabolite-based t-SNE"
        },
        "spatialAxisFixed": {
          "A": false
        },
        "spatialOrbitAxis": {
          "A": null
        },
        "spatialRotation": {
          "A": 0
        },
        "spatialRotationOrbit": {
          "A": -14.282115869017636
        },
        "spatialRotationX": {
          "A": -19.113264220037628
        },
        "spatialRotationY": {
          "A": null
        },
        "spatialRotationZ": {
          "A": null
        },
        "spatialTargetX": {
          "A": 494.0703579375883
        },
        "spatialTargetY": {
          "A": 358.7471084680066
        },
        "spatialTargetZ": {
          "A": 18.79732498306471
        },
        "spatialZoom": {
          "A": -0.7884025211167491
        },
        "spatialImageLayer": {
          "A": null
        },
        "spatialSegmentationLayer": {
          "A": [
              {
                  "channels": [
                    {
                      "color": [
                        255,
                        255,
                        255
                      ],
                      "selection": {
                        "c": 0,
                        "t": 0,
                        "z": 0
                      },
                      "slider": [
                        2,
                        1998
                      ],
                      "visible": true
                    }
                  ],
                  "colormap": null,
                  "domainType": "Min/Max",
                  "index": 0,
                  "opacity": 1,
                  "renderingMode": "Additive",
                  "transparentColor": [
                    0,
                    0,
                    0
                  ],
                  "type": "bitmask",
                  "use3d": false,
                  "visible": true
                }
              ]
        }
      },
      "layout": [
        {
          "component": "spatial",
          "x": 0,
          "y": 0,
          "w": 6,
          "h": 6,
          "coordinationScopes": {
            "spatialAxisFixed": "A",
            "spatialOrbitAxis": "A",
            "spatialRotation": "A",
            "spatialRotationOrbit": "A",
            "spatialRotationX": "A",
            "spatialRotationY": "A",
            "spatialRotationZ": "A",
            "spatialTargetX": "A",
            "spatialTargetY": "A",
            "spatialTargetZ": "A",
            "spatialZoom": "A",
            "spatialImageLayer": "A",
            "spatialSegmentationLayer": "A"
          }
        },
        {
          "component": "layerController",
          "x": 6,
          "y": 0,
          "w": 2,
          "h": 6,
          "coordinationScopes": {
            "spatialAxisFixed": "A",
            "spatialOrbitAxis": "A",
            "spatialRotation": "A",
            "spatialRotationOrbit": "A",
            "spatialRotationX": "A",
            "spatialRotationY": "A",
            "spatialRotationZ": "A",
            "spatialTargetX": "A",
            "spatialTargetY": "A",
            "spatialTargetZ": "A",
            "spatialZoom": "A",
            "spatialImageLayer": "A",
            "spatialSegmentationLayer": "A"
          }
        },
        {
          "component": "heatmap",
          "props": {
            "transpose": true,
            "variablesLabelOverride": "feature"
          },
          "x": 0,
          "y": 6,
          "w": 6,
          "h": 6,
          "coordinationScopes": {
          }
        },
        {
          "component": "obsSets",
          "x": 10,
          "y": 0,
          "w": 2,
          "h": 6,
          "coordinationScopes": {
          }
        },
        {
          "component": "featureList",
          "props": {
            "variablesLabelOverride": "feature"
          },
          "x": 8,
          "y": 0,
          "w": 2,
          "h": 6,
          "coordinationScopes": {
          }
        },
        {
          "component": "scatterplot",
          "x": 6,
          "y": 6,
          "w": 3,
          "h": 6,
          "coordinationScopes": {
            "embeddingType": "A"
          }
        },
        {
          "component": "scatterplot",
          "x": 9,
          "y": 6,
          "w": 3,
          "h": 6,
          "coordinationScopes": {
            "embeddingType": "B"
          }
        }
      ],
      "initStrategy": "auto"
    }
"""

# %%
dict_config = json.loads(json_config)
dict_config
# Out:
# {'version': '1.0.16',
#  'name': '3D Human Liver with annotations',
#  'uid': '3D Human Liver with annotations',
#  'description': '',
#  'datasets': [{'uid': 'human-liver-annot',
#    'name': 'Human dataset',
#    'files': [{'fileType': 'image.ome-tiff',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_3d.raster.pyramid.ome.tiff'},
#     {'fileType': 'obsSegmentations.ome-tiff',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.cell_ids.ome.tiff',
#      'coordinationValues': {'obsType': 'cell'}},
#     {'fileType': 'anndata-cells.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': {'mappings': {'Lipid/metabolite-based t-SNE': {'dims': [0, 1],
#         'key': 'obsm/X_lipmet_tsne'},
#        'Protein-based t-SNE': {'dims': [0, 1], 'key': 'obsm/X_protein_tsne'}},
#       'xy': 'obsm/X_spatial'}},
#     {'fileType': 'anndata-cell-sets.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': [{'groupName': 'Protein-based Clustering',
#        'setName': 'obs/Protein Cluster'},
#       {'groupName': 'Lipid/metabolite-based Clustering',
#        'setName': 'obs/Lipmet Cluster'}]},
#     {'fileType': 'anndata-expression-matrix.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': {'geneAlias': 'var/feature_name',
#       'matrix': 'layers/X_uint8'}}]}],
#  'coordinationSpace': {'embeddingType': {'A': 'Protein-based t-SNE',
#    'B': 'Lipid/metabolite-based t-SNE'},
#   'spatialAxisFixed': {'A': False},
#   'spatialOrbitAxis': {'A': None},
#   'spatialRotation': {'A': 0},
#   'spatialRotationOrbit': {'A': -14.282115869017636},
#   'spatialRotationX': {'A': -19.113264220037628},
#   'spatialRotationY': {'A': None},
#   'spatialRotationZ': {'A': None},
#   'spatialTargetX': {'A': 494.0703579375883},
#   'spatialTargetY': {'A': 358.7471084680066},
#   'spatialTargetZ': {'A': 18.79732498306471},
#   'spatialZoom': {'A': -0.7884025211167491},
#   'spatialImageLayer': {'A': None},
#   'spatialSegmentationLayer': {'A': [{'channels': [{'color': [255, 255, 255],
#        'selection': {'c': 0, 't': 0, 'z': 0},
#        'slider': [2, 1998],
#        'visible': True}],
#      'colormap': None,
#      'domainType': 'Min/Max',
#      'index': 0,
#      'opacity': 1,
#      'renderingMode': 'Additive',
#      'transparentColor': [0, 0, 0],
#      'type': 'bitmask',
#      'use3d': False,
#      'visible': True}]}},
#  'layout': [{'component': 'spatial',
#    'x': 0,
#    'y': 0,
#    'w': 6,
#    'h': 6,
#    'coordinationScopes': {'spatialAxisFixed': 'A',
#     'spatialOrbitAxis': 'A',
#     'spatialRotation': 'A',
#     'spatialRotationOrbit': 'A',
#     'spatialRotationX': 'A',
#     'spatialRotationY': 'A',
#     'spatialRotationZ': 'A',
#     'spatialTargetX': 'A',
#     'spatialTargetY': 'A',
#     'spatialTargetZ': 'A',
#     'spatialZoom': 'A',
#     'spatialImageLayer': 'A',
#     'spatialSegmentationLayer': 'A'}},
#   {'component': 'layerController',
#    'x': 6,
#    'y': 0,
#    'w': 2,
#    'h': 6,
#    'coordinationScopes': {'spatialAxisFixed': 'A',
#     'spatialOrbitAxis': 'A',
#     'spatialRotation': 'A',
#     'spatialRotationOrbit': 'A',
#     'spatialRotationX': 'A',
#     'spatialRotationY': 'A',
#     'spatialRotationZ': 'A',
#     'spatialTargetX': 'A',
#     'spatialTargetY': 'A',
#     'spatialTargetZ': 'A',
#     'spatialZoom': 'A',
#     'spatialImageLayer': 'A',
#     'spatialSegmentationLayer': 'A'}},
#   {'component': 'heatmap',
#    'props': {'transpose': True, 'variablesLabelOverride': 'feature'},
#    'x': 0,
#    'y': 6,
#    'w': 6,
#    'h': 6,
#    'coordinationScopes': {}},
#   {'component': 'obsSets',
#    'x': 10,
#    'y': 0,
#    'w': 2,
#    'h': 6,
#    'coordinationScopes': {}},
#   {'component': 'featureList',
#    'props': {'variablesLabelOverride': 'feature'},
#    'x': 8,
#    'y': 0,
#    'w': 2,
#    'h': 6,
#    'coordinationScopes': {}},
#   {'component': 'scatterplot',
#    'x': 6,
#    'y': 6,
#    'w': 3,
#    'h': 6,
#    'coordinationScopes': {'embeddingType': 'A'}},
#   {'component': 'scatterplot',
#    'x': 9,
#    'y': 6,
#    'w': 3,
#    'h': 6,
#    'coordinationScopes': {'embeddingType': 'B'}}],
#  'initStrategy': 'auto'}

# %%
vc = VitessceConfig.from_dict(dict_config)
del vc.config['coordinationSpace']['dataset']
vc.to_dict()
# Out:
# {'version': '1.0.16',
#  'name': '3D Human Liver with annotations',
#  'description': '',
#  'datasets': [{'uid': 'human-liver-annot',
#    'name': 'Human dataset',
#    'files': [{'fileType': 'image.ome-tiff',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_3d.raster.pyramid.ome.tiff'},
#     {'fileType': 'obsSegmentations.ome-tiff',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.cell_ids.ome.tiff',
#      'coordinationValues': {'obsType': 'cell'}},
#     {'fileType': 'anndata-cells.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': {'mappings': {'Lipid/metabolite-based t-SNE': {'dims': [0, 1],
#         'key': 'obsm/X_lipmet_tsne'},
#        'Protein-based t-SNE': {'dims': [0, 1], 'key': 'obsm/X_protein_tsne'}},
#       'xy': 'obsm/X_spatial'}},
#     {'fileType': 'anndata-cell-sets.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': [{'groupName': 'Protein-based Clustering',
#        'setName': 'obs/Protein Cluster'},
#       {'groupName': 'Lipid/metabolite-based Clustering',
#        'setName': 'obs/Lipmet Cluster'}]},
#     {'fileType': 'anndata-expression-matrix.zarr',
#      'url': 'https://storage.googleapis.com/vitessce-data/0.0.31/master_release/tian/human_topslice.h5ad.zarr',
#      'options': {'geneAlias': 'var/feature_name',
#       'matrix': 'layers/X_uint8'}}]}],
#  'coordinationSpace': {'embeddingType': {'A': 'Protein-based t-SNE',
#    'B': 'Lipid/metabolite-based t-SNE'},
#   'spatialAxisFixed': {'A': False},
#   'spatialOrbitAxis': {'A': None},
#   'spatialRotation': {'A': 0},
#   'spatialRotationOrbit': {'A': -14.282115869017636},
#   'spatialRotationX': {'A': -19.113264220037628},
#   'spatialRotationY': {'A': None},
#   'spatialRotationZ': {'A': None},
#   'spatialTargetX': {'A': 494.0703579375883},
#   'spatialTargetY': {'A': 358.7471084680066},
#   'spatialTargetZ': {'A': 18.79732498306471},
#   'spatialZoom': {'A': -0.7884025211167491},
#   'spatialImageLayer': {'A': None},
#   'spatialSegmentationLayer': {'A': [{'channels': [{'color': [255, 255, 255],
#        'selection': {'c': 0, 't': 0, 'z': 0},
#        'slider': [2, 1998],
#        'visible': True}],
#      'colormap': None,
#      'domainType': 'Min/Max',
#      'index': 0,
#      'opacity': 1,
#      'renderingMode': 'Additive',
#      'transparentColor': [0, 0, 0],
#      'type': 'bitmask',
#      'use3d': False,
#      'visible': True}]}},
#  'layout': [{'component': 'spatial',
#    'coordinationScopes': {'spatialAxisFixed': 'A',
#     'spatialOrbitAxis': 'A',
#     'spatialRotation': 'A',
#     'spatialRotationOrbit': 'A',
#     'spatialRotationX': 'A',
#     'spatialRotationY': 'A',
#     'spatialRotationZ': 'A',
#     'spatialTargetX': 'A',
#     'spatialTargetY': 'A',
#     'spatialTargetZ': 'A',
#     'spatialZoom': 'A',
#     'spatialImageLayer': 'A',
#     'spatialSegmentationLayer': 'A'},
#    'x': 0,
#    'y': 0,
#    'w': 6,
#    'h': 6},
#   {'component': 'layerController',
#    'coordinationScopes': {'spatialAxisFixed': 'A',
#     'spatialOrbitAxis': 'A',
#     'spatialRotation': 'A',
#     'spatialRotationOrbit': 'A',
#     'spatialRotationX': 'A',
#     'spatialRotationY': 'A',
#     'spatialRotationZ': 'A',
#     'spatialTargetX': 'A',
#     'spatialTargetY': 'A',
#     'spatialTargetZ': 'A',
#     'spatialZoom': 'A',
#     'spatialImageLayer': 'A',
#     'spatialSegmentationLayer': 'A'},
#    'x': 6,
#    'y': 0,
#    'w': 2,
#    'h': 6},
#   {'component': 'heatmap',
#    'coordinationScopes': {},
#    'x': 0,
#    'y': 6,
#    'w': 6,
#    'h': 6,
#    'props': {'transpose': True, 'variablesLabelOverride': 'feature'}},
#   {'component': 'obsSets',
#    'coordinationScopes': {},
#    'x': 10,
#    'y': 0,
#    'w': 2,
#    'h': 6},
#   {'component': 'featureList',
#    'coordinationScopes': {},
#    'x': 8,
#    'y': 0,
#    'w': 2,
#    'h': 6,
#    'props': {'variablesLabelOverride': 'feature'}},
#   {'component': 'scatterplot',
#    'coordinationScopes': {'embeddingType': 'A'},
#    'x': 6,
#    'y': 6,
#    'w': 3,
#    'h': 6},
#   {'component': 'scatterplot',
#    'coordinationScopes': {'embeddingType': 'B'},
#    'x': 9,
#    'y': 6,
#    'w': 3,
#    'h': 6}],
#  'initStrategy': 'auto'}

# %%
vc.web_app()
# Out:
# 'http://vitessce.io/#?theme=light&url=data:,%7B%22version%22%3A+%221.0.16%22%2C+%22name%22%3A+%223D+Human+Liver+with+annotations%22%2C+%22description%22%3A+%22%22%2C+%22datasets%22%3A+%5B%7B%22uid%22%3A+%22human-liver-annot%22%2C+%22name%22%3A+%22Human+dataset%22%2C+%22files%22%3A+%5B%7B%22fileType%22%3A+%22image.ome-tiff%22%2C+%22url%22%3A+%22https%3A%2F%2Fstorage.googleapis.com%2Fvitessce-data%2F0.0.31%2Fmaster_release%2Ftian%2Fhuman_3d.raster.pyramid.ome.tiff%22%7D%2C+%7B%22fileType%22%3A+%22obsSegmentations.ome-tiff%22%2C+%22url%22%3A+%22https%3A%2F%2Fstorage.googleapis.com%2Fvitessce-data%2F0.0.31%2Fmaster_release%2Ftian%2Fhuman_topslice.cell_ids.ome.tiff%22%2C+%22coordinationValues%22%3A+%7B%22obsType%22%3A+%22cell%22%7D%7D%2C+%7B%22fileType%22%3A+%22anndata-cells.zarr%22%2C+%22url%22%3A+%22https%3A%2F%2Fstorage.googleapis.com%2Fvitessce-data%2F0.0.31%2Fmaster_release%2Ftian%2Fhuman_topslice.h5ad.zarr%22%2C+%22options%22%3A+%7B%22mappings%22%3A+%7B%22Lipid%2Fmetabolite-based+t-SNE%22%3A+%7B%22dims%22%3A+%5B0%2C+1%5D%2C+%22key%22%3A+%22obsm%2FX_lipmet_tsne%22%7D%2C+%22Protein-based+t-SNE%22%3A+%7B%22dims%22%3A+%5B0%2C+1%5D%2C+%22key%22%3A+%22obsm%2FX_protein_tsne%22%7D%7D%2C+%22xy%22%3A+%22obsm%2FX_spatial%22%7D%7D%2C+%7B%22fileType%22%3A+%22anndata-cell-sets.zarr%22%2C+%22url%22%3A+%22https%3A%2F%2Fstorage.googleapis.com%2Fvitessce-data%2F0.0.31%2Fmaster_release%2Ftian%2Fhuman_topslice.h5ad.zarr%22%2C+%22options%22%3A+%5B%7B%22groupName%22%3A+%22Protein-based+Clustering%22%2C+%22setName%22%3A+%22obs%2FProtein+Cluster%22%7D%2C+%7B%22groupName%22%3A+%22Lipid%2Fmetabolite-based+Clustering%22%2C+%22setName%22%3A+%22obs%2FLipmet+Cluster%22%7D%5D%7D%2C+%7B%22fileType%22%3A+%22anndata-expression-matrix.zarr%22%2C+%22url%22%3A+%22https%3A%2F%2Fstorage.googleapis.com%2Fvitessce-data%2F0.0.31%2Fmaster_release%2Ftian%2Fhuman_topslice.h5ad.zarr%22%2C+%22options%22%3A+%7B%22geneAlias%22%3A+%22var%2Ffeature_name%22%2C+%22matrix%22%3A+%22layers%2FX_uint8%22%7D%7D%5D%7D%5D%2C+%22coordinationSpace%22%3A+%7B%22embeddingType%22%3A+%7B%22A%22%3A+%22Protein-based+t-SNE%22%2C+%22B%22%3A+%22Lipid%2Fmetabolite-based+t-SNE%22%7D%2C+%22spatialAxisFixed%22%3A+%7B%22A%22%3A+false%7D%2C+%22spatialOrbitAxis%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialRotation%22%3A+%7B%22A%22%3A+0%7D%2C+%22spatialRotationOrbit%22%3A+%7B%22A%22%3A+-14.282115869017636%7D%2C+%22spatialRotationX%22%3A+%7B%22A%22%3A+-19.113264220037628%7D%2C+%22spatialRotationY%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialRotationZ%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialTargetX%22%3A+%7B%22A%22%3A+494.0703579375883%7D%2C+%22spatialTargetY%22%3A+%7B%22A%22%3A+358.7471084680066%7D%2C+%22spatialTargetZ%22%3A+%7B%22A%22%3A+18.79732498306471%7D%2C+%22spatialZoom%22%3A+%7B%22A%22%3A+-0.7884025211167491%7D%2C+%22spatialImageLayer%22%3A+%7B%22A%22%3A+null%7D%2C+%22spatialSegmentationLayer%22%3A+%7B%22A%22%3A+%5B%7B%22channels%22%3A+%5B%7B%22color%22%3A+%5B255%2C+255%2C+255%5D%2C+%22selection%22%3A+%7B%22c%22%3A+0%2C+%22t%22%3A+0%2C+%22z%22%3A+0%7D%2C+%22slider%22%3A+%5B2%2C+1998%5D%2C+%22visible%22%3A+true%7D%5D%2C+%22colormap%22%3A+null%2C+%22domainType%22%3A+%22Min%2FMax%22%2C+%22index%22%3A+0%2C+%22opacity%22%3A+1%2C+%22renderingMode%22%3A+%22Additive%22%2C+%22transparentColor%22%3A+%5B0%2C+0%2C+0%5D%2C+%22type%22%3A+%22bitmask%22%2C+%22use3d%22%3A+false%2C+%22visible%22%3A+true%7D%5D%7D%7D%2C+%22layout%22%3A+%5B%7B%22component%22%3A+%22spatial%22%2C+%22coordinationScopes%22%3A+%7B%22spatialAxisFixed%22%3A+%22A%22%2C+%22spatialOrbitAxis%22%3A+%22A%22%2C+%22spatialRotation%22%3A+%22A%22%2C+%22spatialRotationOrbit%22%3A+%22A%22%2C+%22spatialRotationX%22%3A+%22A%22%2C+%22spatialRotationY%22%3A+%22A%22%2C+%22spatialRotationZ%22%3A+%22A%22%2C+%22spatialTargetX%22%3A+%22A%22%2C+%22spatialTargetY%22%3A+%22A%22%2C+%22spatialTargetZ%22%3A+%22A%22%2C+%22spatialZoom%22%3A+%22A%22%2C+%22spatialImageLayer%22%3A+%22A%22%2C+%22spatialSegmentationLayer%22%3A+%22A%22%7D%2C+%22x%22%3A+0%2C+%22y%22%3A+0%2C+%22w%22%3A ...
